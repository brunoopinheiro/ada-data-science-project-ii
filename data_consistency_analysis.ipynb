# %%
import pandas as pd
from datasets.get_dataset import get_file_path

json_path = get_file_path()

mtg_dataset = pd.read_json(json_path)

(mtg_dataset.head())
# Out:
#   object                                    id  \
# 0   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2   card  0000a54c-a511-4925-92dc-01b937f9afad
# 3   card  0000cd57-91fe-411f-b798-646e965eec37
# 4   card  00012bd8-ed68-4978-a22d-f450c8a6e048
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0       25528.0
# 1  8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0       34587.0
# 2  dc4e2134-f0c2-49aa-9ea3-ebf83af1445c             []      NaN           NaN
# 3  9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0       65171.0
# 4  5aa12aff-db3c-4be5-822b-3afdf536b33e         [1278]      NaN           NaN
#
#    tcgplayer_id  cardmarket_id           name lang  ... tcgplayer_etched_id  \
# 0       14240.0        13850.0    Fury Sliver   en  ...                 NaN
# 1       33347.0        21851.0  Kor Outfitter   en  ...                 NaN
# 2       98659.0            NaN         Spirit   en  ...                 NaN
# 3      145764.0       301766.0  Siren Lookout   en  ...                 NaN
# 4        1623.0         5664.0            Web   en  ...                 NaN
#
#   flavor_name attraction_lights color_indicator  printed_type_line  \
# 0         NaN               NaN             NaN                NaN
# 1         NaN               NaN             NaN                NaN
# 2         NaN               NaN             NaN                NaN
# 3         NaN               NaN             NaN                NaN
# 4         NaN               NaN             NaN                NaN
#
#   printed_text variation_of life_modifier  hand_modifier content_warning
# 0          NaN          NaN           NaN            NaN             NaN
# 1          NaN          NaN           NaN            NaN             NaN
# 2          NaN          NaN           NaN            NaN             NaN
# 3          NaN          NaN           NaN            NaN             NaN
# 4          NaN          NaN           NaN            NaN             NaN
#
# [5 rows x 85 columns]

# %%
(mtg_dataset.columns)
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
#        'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
#        'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id',
#        'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri',
#        'scryfall_set_uri', 'rulings_uri', 'prints_search_uri',
#        'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id',
#        'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
#        'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank',
#        'penny_rank', 'prices', 'related_uris', 'purchase_uris', 'all_parts',
#        'promo_types', 'arena_id', 'security_stamp', 'card_faces', 'preview',
#        'produced_mana', 'watermark', 'frame_effects', 'loyalty',
#        'printed_name', 'tcgplayer_etched_id', 'flavor_name',
#        'attraction_lights', 'color_indicator', 'printed_type_line',
#        'printed_text', 'variation_of', 'life_modifier', 'hand_modifier',
#        'content_warning'],
#       dtype='object')

# %%
data_significant_columns = [
    "id",
    "name",
    "released_at",
    "mana_cost",
    "cmc",
    "colors",
    "color_identity",
    "keywords",
    "legalities",
    "set",
    "set_name",
    "rarity",
    "power",
    "toughness",
    "type_line",
    "oracle_text",
    "flavor_text",
    "edhrec_rank",
    "produced_mana",
    "loyalty",
    "printed_name",
    "flavor_name",
    "life_modifier",
    "hand_modifier",
]

subset = mtg_dataset[data_significant_columns]

(subset.head())
# Out:
#                                      id           name released_at mana_cost  \
# 0  0000579f-7b35-4ed3-b44c-db2a538066fe    Fury Sliver  2006-10-06    {5}{R}
# 1  00006596-1166-4a79-8443-ca9f82e6db4e  Kor Outfitter  2009-10-02    {W}{W}
# 2  0000a54c-a511-4925-92dc-01b937f9afad         Spirit  2015-05-22
# 3  0000cd57-91fe-411f-b798-646e965eec37  Siren Lookout  2017-09-29    {2}{U}
# 4  00012bd8-ed68-4978-a22d-f450c8a6e048            Web  1994-04-01       {G}
#
#    cmc colors color_identity           keywords  \
# 0  6.0    [R]            [R]                 []
# 1  2.0    [W]            [W]                 []
# 2  0.0    [W]            [W]           [Flying]
# 3  3.0    [U]            [U]  [Flying, Explore]
# 4  1.0    [G]            [G]          [Enchant]
#
#                                           legalities   set  ...  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...   tsp  ...
# 1  {'standard': 'not_legal', 'future': 'not_legal...   zen  ...
# 2  {'standard': 'not_legal', 'future': 'not_legal...  tmm2  ...
# 3  {'standard': 'not_legal', 'future': 'not_legal...   xln  ...
# 4  {'standard': 'not_legal', 'future': 'not_legal...   3ed  ...
#
#                  type_line                                        oracle_text  \
# 0        Creature — Sliver           All Sliver creatures have double strike.
# 1   Creature — Kor Soldier  When Kor Outfitter enters the battlefield, you...
# 2  Token Creature — Spirit                                             Flying
# 3  Creature — Siren Pirate  Flying\nWhen Siren Lookout enters the battlefi...
# 4       Enchantment — Aura  Enchant creature (Target a creature as you cas...
#
#                                          flavor_text edhrec_rank  \
# 0  "A rift opened, and our arrows were abruptly s...      6932.0
# 1  "We take only what we need to survive. Believe...     16446.0
# 2                                                NaN         NaN
# 3                                                NaN     14297.0
# 4                                                NaN     22177.0
#
#   produced_mana loyalty printed_name  flavor_name life_modifier hand_modifier
# 0           NaN     NaN          NaN          NaN           NaN           NaN
# 1           NaN     NaN          NaN          NaN           NaN           NaN
# 2           NaN     NaN          NaN          NaN           NaN           NaN
# 3           NaN     NaN          NaN          NaN           NaN           NaN
# 4           NaN     NaN          NaN          NaN           NaN           NaN
#
# [5 rows x 24 columns]

# %%
# A quantidade de colunas ainda é muito grande pra gerar bons resultados. Melhor tentar dividir por sub-temas.

card_analysis = [
    "name",
    "mana_cost",
    "cmc",
    "colors",
    "color_identity",
    "keywords",
    "power",
    "toughness",
    "type_line",
    "edhrec_rank",
    "produced_mana",
    "loyalty",
    "life_modifier",
    "hand_modifier",
]

subset = mtg_dataset[card_analysis]

(subset.head(15))
# Out:
#                                      name         mana_cost  cmc colors  \
# 0                             Fury Sliver            {5}{R}  6.0    [R]
# 1                           Kor Outfitter            {W}{W}  2.0    [W]
# 2                                  Spirit                    0.0    [W]
# 3                           Siren Lookout            {2}{U}  3.0    [U]
# 4                                     Web               {G}  1.0    [G]
# 5                     Surge of Brilliance            {1}{U}  2.0    [U]
# 6   Obyra's Attendants // Desperate Parry  {4}{U} // {1}{U}  5.0    [U]
# 7                        Venerable Knight               {W}  1.0    [W]
# 8                                Wildcall         {X}{G}{G}  2.0    [G]
# 9                          Mystic Skyfish            {2}{U}  3.0    [U]
# 10                                  Swamp                    0.0     []
# 11                                  Swamp                    0.0     []
# 12                      Battlewing Mystic            {1}{U}  2.0    [U]
# 13                      Birds of Paradise               {G}  1.0    [G]
# 14                           Bronze Horse               {7}  7.0     []
#
#    color_identity             keywords power toughness  \
# 0             [R]                   []     3         3
# 1             [W]                   []     2         2
# 2             [W]             [Flying]     1         1
# 3             [U]    [Flying, Explore]     1         2
# 4             [G]            [Enchant]   NaN       NaN
# 5             [U]  [Paradox, Foretell]   NaN       NaN
# 6             [U]             [Flying]     3         4
# 7             [W]                   []     2         1
# 8             [G]           [Manifest]   NaN       NaN
# 9             [U]                   []     3         1
# 10            [B]                   []   NaN       NaN
# 11            [B]                   []   NaN       NaN
# 12         [R, U]     [Kicker, Flying]     2         1
# 13            [G]             [Flying]     0         1
# 14             []            [Trample]     4         4
#
#                                           type_line  edhrec_rank  \
# 0                                 Creature — Sliver       6932.0
# 1                            Creature — Kor Soldier      16446.0
# 2                           Token Creature — Spirit          NaN
# 3                           Creature — Siren Pirate      14297.0
# 4                                Enchantment — Aura      22177.0
# 5                                           Instant      11141.0
# 6   Creature — Faerie Wizard // Instant — Adventure      16512.0
# 7                           Creature — Human Knight      14622.0
# 8                                           Sorcery      17981.0
# 9                                   Creature — Fish      23204.0
# 10                               Basic Land — Swamp          NaN
# 11                               Basic Land — Swamp          NaN
# 12                           Creature — Bird Wizard      19982.0
# 13                                  Creature — Bird         45.0
# 14                        Artifact Creature — Horse      20596.0
#
#       produced_mana loyalty  life_modifier  hand_modifier
# 0               NaN     NaN            NaN            NaN
# 1               NaN     NaN            NaN            NaN
# 2               NaN     NaN            NaN            NaN
# 3               NaN     NaN            NaN            NaN
# 4               NaN     NaN            NaN            NaN
# 5               NaN     NaN            NaN            NaN
# 6               NaN     NaN            NaN            NaN
# 7               NaN     NaN            NaN            NaN
# 8               NaN     NaN            NaN            NaN
# 9               NaN     NaN            NaN            NaN
# 10              [B]     NaN            NaN            NaN
# 11              [B]     NaN            NaN            NaN
# 12              NaN     NaN            NaN            NaN
# 13  [B, G, R, U, W]     NaN            NaN            NaN
# 14              NaN     NaN            NaN            NaN

# %%
import datasets.get_dataset as gd

# print(gd.get_file_path())

# Essa função foi implementada exportando, por padrão, o dataset com a lista de colunas definida na célula de cima.
mtg_subset = gd.get_subset()

(mtg_subset.head())
# Out:
#             name mana_cost  cmc colors color_identity           keywords  \
# 0    Fury Sliver    {5}{R}  6.0    [R]            [R]                 []
# 1  Kor Outfitter    {W}{W}  2.0    [W]            [W]                 []
# 2         Spirit            0.0    [W]            [W]           [Flying]
# 3  Siren Lookout    {2}{U}  3.0    [U]            [U]  [Flying, Explore]
# 4            Web       {G}  1.0    [G]            [G]          [Enchant]
#
#   power toughness                type_line  edhrec_rank produced_mana loyalty  \
# 0     3         3        Creature — Sliver       6932.0           NaN     NaN
# 1     2         2   Creature — Kor Soldier      16446.0           NaN     NaN
# 2     1         1  Token Creature — Spirit          NaN           NaN     NaN
# 3     1         2  Creature — Siren Pirate      14297.0           NaN     NaN
# 4   NaN       NaN       Enchantment — Aura      22177.0           NaN     NaN
#
#    life_modifier  hand_modifier
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN

# %%
mtg_subset.isnull().sum()
# Out:
# name                  0
# mana_cost          2898
# cmc                  51
# colors             2898
# color_identity        0
# keywords              0
# power             49036
# toughness         49036
# type_line            51
# edhrec_rank       11348
# produced_mana     78465
# loyalty           91044
# life_modifier     92272
# hand_modifier     92272
# dtype: int64

# %%
mtg_subset.describe()
# Out:
#                   cmc   edhrec_rank  life_modifier  hand_modifier
# count    92340.000000  81043.000000     119.000000     119.000000
# mean        24.507326  10057.767198       1.084034       0.084034
# std       4653.894301   7896.178469       5.683130       1.211385
# min          0.000000      1.000000      -8.000000      -4.000000
# 25%          1.000000   2856.000000      -3.000000      -1.000000
# 50%          3.000000   8555.000000       0.000000       0.000000
# 75%          4.000000  16533.000000       4.000000       1.000000
# max    1000000.000000  26571.000000      30.000000       3.000000

# %%
mtg_subset.sample()
# Out:
#                             name     mana_cost  cmc  colors color_identity  \
# 25507  Maja, Bretagard Protector  {2}{G}{W}{W}  5.0  [G, W]         [G, W]
#
#          keywords power toughness                           type_line  \
# 25507  [Landfall]     2         3  Legendary Creature — Human Warrior
#
#        edhrec_rank produced_mana loyalty  life_modifier  hand_modifier
# 25507       1834.0           NaN     NaN            NaN            NaN

# %%
# Obtendo cada valor único possível da lista de identidade de cor das cartas.
unique_values = pd.unique(mtg_subset['color_identity'].apply('-'.join))

(unique_values)
# Out:
# array(['R', 'W', 'U', 'G', 'B', 'R-U', '', 'B-R-U', 'B-W', 'U-W', 'B-U-W',
#        'B-G-R', 'G-U-W', 'G-U', 'G-R', 'B-G', 'B-U', 'B-R-W', 'G-W',
#        'R-W', 'B-G-R-U-W', 'G-R-W', 'G-R-U', 'B-R', 'R-U-W', 'B-G-U',
#        'B-R-U-W', 'B-G-W', 'G-R-U-W', 'B-G-R-U', 'B-G-U-W', 'B-G-R-W'],
#       dtype=object)

# %%
mtg_subset['color_identity'] = mtg_subset['color_identity'].apply('-'.join)

(mtg_subset.head())
# Out:
#             name mana_cost  cmc colors color_identity           keywords  \
# 0    Fury Sliver    {5}{R}  6.0    [R]              R                 []
# 1  Kor Outfitter    {W}{W}  2.0    [W]              W                 []
# 2         Spirit            0.0    [W]              W           [Flying]
# 3  Siren Lookout    {2}{U}  3.0    [U]              U  [Flying, Explore]
# 4            Web       {G}  1.0    [G]              G          [Enchant]
#
#   power toughness                type_line  edhrec_rank produced_mana loyalty  \
# 0     3         3        Creature — Sliver       6932.0           NaN     NaN
# 1     2         2   Creature — Kor Soldier      16446.0           NaN     NaN
# 2     1         1  Token Creature — Spirit          NaN           NaN     NaN
# 3     1         2  Creature — Siren Pirate      14297.0           NaN     NaN
# 4   NaN       NaN       Enchantment — Aura      22177.0           NaN     NaN
#
#    life_modifier  hand_modifier
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN

# %%
mtg_subset.groupby('color_identity').describe()
# Out:
#                     cmc                                                \
#                   count        mean           std  min  25%  50%  75%
# color_identity
#                 12466.0  162.311648  12665.816962  0.0  0.0  1.0  3.0
# B               12926.0    3.026071      1.904778  0.0  2.0  3.0  4.0
# B-G              1159.0    2.895600      1.953777  0.0  2.0  3.0  4.0
# B-G-R             253.0    4.019763      2.170236  0.0  3.0  4.0  6.0
# B-G-R-U             7.0    4.000000      0.000000  4.0  4.0  4.0  4.0
# B-G-R-U-W         355.0    4.929577      2.210171  0.0  4.0  5.0  6.0
# B-G-R-W             6.0    4.000000      0.000000  4.0  4.0  4.0  4.0
# B-G-U             184.0    4.043478      1.761228  0.0  3.0  4.0  5.0
# B-G-U-W            21.0    4.857143      1.388730  4.0  4.0  4.0  7.0
# B-G-W             167.0    3.946108      2.316149  0.0  3.0  4.0  5.0
# B-R              1336.0    2.923653      2.108341  0.0  2.0  3.0  4.0
# B-R-U             371.0    4.423181      2.020544  0.0  3.0  4.0  6.0
# B-R-U-W             7.0    4.000000      0.000000  4.0  4.0  4.0  4.0
# B-R-W             190.0    4.068421      1.877337  0.0  3.0  4.0  5.0
# B-U              1397.0    2.785970      2.050754  0.0  2.0  3.0  4.0
# B-U-W             276.0    3.923913      1.964598  0.0  3.0  4.0  5.0
# B-W              1193.0    2.800503      1.918324  0.0  2.0  3.0  4.0
# G               13279.0    2.995256      2.021810  0.0  2.0  3.0  4.0
# G-R              1318.0    2.790592      2.065776  0.0  1.0  3.0  4.0
# G-R-U             161.0    4.055901      2.095377  0.0  3.0  4.0  5.0
# G-R-U-W            21.0    4.000000      0.316228  3.0  4.0  4.0  4.0
# G-R-W             298.0    3.822148      2.117407  0.0  3.0  3.0  5.0
# G-U              1214.0    2.924217      1.953083  0.0  2.0  3.0  4.0
# G-U-W             261.0    3.613027      1.955186  0.0  3.0  4.0  5.0
# G-W              1417.0    2.652082      2.022730  0.0  1.0  3.0  4.0
# R               12650.0    3.006719      1.913342  0.0  2.0  3.0  4.0
# R-U              1177.0    2.922685      1.995736  0.0  2.0  3.0  4.0
# R-U-W             187.0    3.925134      1.686365  0.0  3.0  4.0  5.0
# R-W              1229.0    2.802278      1.932272  0.0  2.0  3.0  4.0
# U               12481.0    3.070908      1.911551  0.0  2.0  3.0  4.0
# U-W              1392.0    2.749282      1.921818  0.0  2.0  3.0  4.0
# W               12941.0    2.842400      1.833988  0.0  2.0  3.0  4.0
#
#                           edhrec_rank                ... life_modifier        \
#                       max       count          mean  ...           75%   max
# color_identity                                       ...
#                 1000000.0      8947.0   7640.230468  ...           4.0  30.0
# B                    15.0     11499.0  11057.622576  ...           NaN   NaN
# B-G                  12.0      1103.0   6615.495014  ...           NaN   NaN
# B-G-R                 9.0       243.0  10161.242798  ...           NaN   NaN
# B-G-R-U               4.0         7.0   7911.000000  ...           NaN   NaN
# B-G-R-U-W            13.0       326.0   7573.481595  ...           NaN   NaN
# B-G-R-W               4.0         6.0   9514.666667  ...           NaN   NaN
# B-G-U                 8.0       178.0   8168.230337  ...           NaN   NaN
# B-G-U-W               7.0        20.0   3244.400000  ...           NaN   NaN
# B-G-W                 8.0       165.0   6887.678788  ...           NaN   NaN
# B-R                  11.0      1304.0   8506.977761  ...           NaN   NaN
# B-R-U                 8.0       366.0   8843.092896  ...           NaN   NaN
# B-R-U-W               4.0         7.0   6849.571429  ...           NaN   NaN
# B-R-W                 8.0       188.0   7149.127660  ...           NaN   NaN
# B-U                  11.0      1356.0   7606.862094  ...           NaN   NaN
# B-U-W                 8.0       272.0   9063.863971  ...           NaN   NaN
# B-W                   8.0      1136.0   6846.973592  ...           NaN   NaN
# G                    15.0     11660.0  10058.700086  ...           NaN   NaN
# G-R                   8.0      1270.0   8409.303937  ...           NaN   NaN
# G-R-U                 8.0       161.0   7342.298137  ...           NaN   NaN
# G-R-U-W               5.0        19.0   5012.105263  ...           NaN   NaN
# G-R-W                 9.0       294.0   9927.105442  ...           NaN   NaN
# G-U                  11.0      1183.0   6451.719358  ...           NaN   NaN
# G-U-W                 8.0       256.0   9798.136719  ...           NaN   NaN
# G-W                  15.0      1363.0   7867.325018  ...           NaN   NaN
# R                    12.0     11325.0  11868.849448  ...           NaN   NaN
# R-U                   8.0      1119.0   7697.996425  ...           NaN   NaN
# R-U-W                 9.0       181.0   9080.850829  ...           NaN   NaN
# R-W                   9.0      1165.0   7471.383691  ...           NaN   NaN
# U                    14.0     11177.0  10706.190570  ...           NaN   NaN
# U-W                   9.0      1346.0   8140.558692  ...           NaN   NaN
# W                    11.0     11401.0  11516.454785  ...           NaN   NaN
#
#                hand_modifier
#                        count      mean       std  min  25%  50%  75%  max
# color_identity
#                        119.0  0.084034  1.211385 -4.0 -1.0  0.0  1.0  3.0
# B                        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-R                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-R-U                  0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-R-U-W                0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-R-W                  0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-U                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-U-W                  0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-G-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-R                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-R-U                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-R-U-W                  0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-R-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-U                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-U-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# B-W                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G                        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-R                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-R-U                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-R-U-W                  0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-R-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-U                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-U-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# G-W                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# R                        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# R-U                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# R-U-W                    0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# R-W                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# U                        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# U-W                      0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# W                        0.0       NaN       NaN  NaN  NaN  NaN  NaN  NaN
#
# [32 rows x 32 columns]

# %%
import datasets.get_dataset as gd

# Essa função aplica por padrão uma função de concatenação em todas as colunas cujos valores sejam do tipo list.
mtgflattened = gd.get_flattened_subset()

(mtgflattened.head(20))
# Out:
#                                      name         mana_cost  cmc     colors  \
# 0                             Fury Sliver            {5}{R}  6.0        [R]
# 1                           Kor Outfitter            {W}{W}  2.0        [W]
# 2                                  Spirit                    0.0        [W]
# 3                           Siren Lookout            {2}{U}  3.0        [U]
# 4                                     Web               {G}  1.0        [G]
# 5                     Surge of Brilliance            {1}{U}  2.0        [U]
# 6   Obyra's Attendants // Desperate Parry  {4}{U} // {1}{U}  5.0        [U]
# 7                        Venerable Knight               {W}  1.0        [W]
# 8                                Wildcall         {X}{G}{G}  2.0        [G]
# 9                          Mystic Skyfish            {2}{U}  3.0        [U]
# 10                                  Swamp                    0.0         []
# 11                                  Swamp                    0.0         []
# 12                      Battlewing Mystic            {1}{U}  2.0        [U]
# 13                      Birds of Paradise               {G}  1.0        [G]
# 14                           Bronze Horse               {7}  7.0         []
# 15                         Wall of Vipers            {2}{B}  3.0        [B]
# 16                  Admiral Beckett Brass      {1}{U}{B}{R}  4.0  [B, R, U]
# 17                                  Mulch            {1}{G}  2.0        [G]
# 18                       Whiptongue Hydra            {5}{G}  6.0        [G]
# 19                          Wall of Roots            {1}{G}  2.0        [G]
#
#    color_identity            keywords power toughness  \
# 0               R                         3         3
# 1               W                         2         2
# 2               W              Flying     1         1
# 3               U    Flying | Explore     1         2
# 4               G             Enchant   NaN       NaN
# 5               U  Paradox | Foretell   NaN       NaN
# 6               U              Flying     3         4
# 7               W                         2         1
# 8               G            Manifest   NaN       NaN
# 9               U                         3         1
# 10              B                       NaN       NaN
# 11              B                       NaN       NaN
# 12          R | U     Kicker | Flying     2         1
# 13              G              Flying     0         1
# 14                            Trample     4         4
# 15              B            Defender     2         4
# 16      B | R | U                         3         3
# 17              G                       NaN       NaN
# 18              G               Reach     4         4
# 19              G            Defender     0         5
#
#                                           type_line  edhrec_rank  \
# 0                                 Creature — Sliver       6932.0
# 1                            Creature — Kor Soldier      16446.0
# 2                           Token Creature — Spirit          NaN
# 3                           Creature — Siren Pirate      14297.0
# 4                                Enchantment — Aura      22177.0
# 5                                           Instant      11141.0
# 6   Creature — Faerie Wizard // Instant — Adventure      16512.0
# 7                           Creature — Human Knight      14622.0
# 8                                           Sorcery      17981.0
# 9                                   Creature — Fish      23204.0
# 10                               Basic Land — Swamp          NaN
# 11                               Basic Land — Swamp          NaN
# 12                           Creature — Bird Wizard      19982.0
# 13                                  Creature — Bird         45.0
# 14                        Artifact Creature — Horse      20596.0
# 15                            Creature — Snake Wall      24679.0
# 16                Legendary Creature — Human Pirate       5152.0
# 17                                          Sorcery       4269.0
# 18                          Creature — Lizard Hydra       4421.0
# 19                            Creature — Plant Wall       3274.0
#
#       produced_mana loyalty  life_modifier  hand_modifier
# 0               NaN     NaN            NaN            NaN
# 1               NaN     NaN            NaN            NaN
# 2               NaN     NaN            NaN            NaN
# 3               NaN     NaN            NaN            NaN
# 4               NaN     NaN            NaN            NaN
# 5               NaN     NaN            NaN            NaN
# 6               NaN     NaN            NaN            NaN
# 7               NaN     NaN            NaN            NaN
# 8               NaN     NaN            NaN            NaN
# 9               NaN     NaN            NaN            NaN
# 10              [B]     NaN            NaN            NaN
# 11              [B]     NaN            NaN            NaN
# 12              NaN     NaN            NaN            NaN
# 13  [B, G, R, U, W]     NaN            NaN            NaN
# 14              NaN     NaN            NaN            NaN
# 15              NaN     NaN            NaN            NaN
# 16              NaN     NaN            NaN            NaN
# 17              NaN     NaN            NaN            NaN
# 18              NaN     NaN            NaN            NaN
# 19              [G]     NaN            NaN            NaN

# %%
import numpy as np


numeric_columns = ['cmc', 'power', 'toughness', 'edhrec_rank']

mtg_numeric = gd.get_subset(subset_columns=numeric_columns)

mtg_numeric.apply(pd.to_numeric, errors='coerce')
mtg_numeric.replace(regex=r'[^0-9]', value=np.nan, inplace=True)
mtg_numeric.dropna(inplace=True)

mtg_numeric.corr()
# Out:
#                   cmc     power  toughness  edhrec_rank
# cmc          1.000000  0.729184   0.710869    -0.039340
# power        0.729184  1.000000   0.738913    -0.055545
# toughness    0.710869  0.738913   1.000000    -0.085350
# edhrec_rank -0.039340 -0.055545  -0.085350     1.000000
