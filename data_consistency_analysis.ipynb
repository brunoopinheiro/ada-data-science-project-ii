# %%
import pandas as pd
from datasets.get_dataset import get_file_path

json_path = get_file_path()

mtg_dataset = pd.read_json(json_path)

(mtg_dataset.head())
# Out:
#   object                                    id  \
# 0   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2   card  0000a54c-a511-4925-92dc-01b937f9afad
# 3   card  0000cd57-91fe-411f-b798-646e965eec37
# 4   card  00012bd8-ed68-4978-a22d-f450c8a6e048
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0       25528.0
# 1  8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0       34587.0
# 2  dc4e2134-f0c2-49aa-9ea3-ebf83af1445c             []      NaN           NaN
# 3  9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0       65171.0
# 4  5aa12aff-db3c-4be5-822b-3afdf536b33e         [1278]      NaN           NaN
#
#    tcgplayer_id  cardmarket_id           name lang  ... tcgplayer_etched_id  \
# 0       14240.0        13850.0    Fury Sliver   en  ...                 NaN
# ...

# %%
(mtg_dataset.columns)
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
#        'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
#        'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id',
#        'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri',
#        'scryfall_set_uri', 'rulings_uri', 'prints_search_uri',
#        'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id',
#        'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
#        'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank',
#        'penny_rank', 'prices', 'related_uris', 'purchase_uris', 'all_parts',
# ...

# %%
data_significant_columns = ['id', 'name', 'released_at', 'mana_cost', 'cmc', 'color_identity', 'keywords', 'legalities', 'set', 'set_name', 'rarity', 'type_line', 'oracle_text', 'flavor_text', 'edhrec_rank', 'produced_mana', 'loyalty', 'printed_name', 'flavor_name', 'life_modifier', 'hand_modifier']

subset = mtg_dataset[data_significant_columns]

(subset.head())
# Out:
#                                      id           name released_at mana_cost  \
# 0  0000579f-7b35-4ed3-b44c-db2a538066fe    Fury Sliver  2006-10-06    {5}{R}
# 1  00006596-1166-4a79-8443-ca9f82e6db4e  Kor Outfitter  2009-10-02    {W}{W}
# 2  0000a54c-a511-4925-92dc-01b937f9afad         Spirit  2015-05-22
# 3  0000cd57-91fe-411f-b798-646e965eec37  Siren Lookout  2017-09-29    {2}{U}
# 4  00012bd8-ed68-4978-a22d-f450c8a6e048            Web  1994-04-01       {G}
#
#    cmc color_identity           keywords  \
# 0  6.0            [R]                 []
# 1  2.0            [W]                 []
# 2  0.0            [W]           [Flying]
# 3  3.0            [U]  [Flying, Explore]
# 4  1.0            [G]          [Enchant]
#
#                                           legalities   set  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...   tsp
# 1  {'standard': 'not_legal', 'future': 'not_legal...   zen
# 2  {'standard': 'not_legal', 'future': 'not_legal...  tmm2
# ...

# %%
import datasets.get_dataset as gd

# print(gd.get_file_path())

subset_test = gd.get_subset()

(subset_test.head())
# Out:
#                                      id           name released_at mana_cost  \
# 0  0000579f-7b35-4ed3-b44c-db2a538066fe    Fury Sliver  2006-10-06    {5}{R}
# 1  00006596-1166-4a79-8443-ca9f82e6db4e  Kor Outfitter  2009-10-02    {W}{W}
# 2  0000a54c-a511-4925-92dc-01b937f9afad         Spirit  2015-05-22
# 3  0000cd57-91fe-411f-b798-646e965eec37  Siren Lookout  2017-09-29    {2}{U}
# 4  00012bd8-ed68-4978-a22d-f450c8a6e048            Web  1994-04-01       {G}
#
#    cmc color_identity           keywords  \
# 0  6.0            [R]                 []
# 1  2.0            [W]                 []
# 2  0.0            [W]           [Flying]
# 3  3.0            [U]  [Flying, Explore]
# 4  1.0            [G]          [Enchant]
#
#                                           legalities   set  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...   tsp
# 1  {'standard': 'not_legal', 'future': 'not_legal...   zen
# 2  {'standard': 'not_legal', 'future': 'not_legal...  tmm2
# ...

# %%
subset_test.isnull().sum()
# Out:
# id                    0
# name                  0
# released_at           0
# mana_cost          2890
# cmc                  43
# color_identity        0
# keywords              0
# legalities            0
# set                   0
# set_name              0
# rarity                0
# type_line            43
# oracle_text        3504
# flavor_text       48391
# edhrec_rank       11256
# produced_mana     78343
# loyalty           90870
# printed_name      89986
# flavor_name       91995
# life_modifier     92098
# hand_modifier     92098
# dtype: int64

# %%
subset_test.describe()
# Out:
#                          released_at             cmc   edhrec_rank  \
# count                          92217    92174.000000  80961.000000
# mean   2014-12-21 04:46:30.617782016       24.546580  10061.820605
# min              1993-08-05 00:00:00        0.000000      1.000000
# 25%              2009-08-28 00:00:00        1.000000   2860.000000
# 50%              2018-10-05 00:00:00        3.000000   8558.000000
# 75%              2022-04-29 00:00:00        4.000000  16517.000000
# max              2024-10-01 00:00:00  1000000.000000  26570.000000
# std                              NaN     4658.083064   7895.793960
#
#        life_modifier  hand_modifier
# count     119.000000     119.000000
# mean        1.084034       0.084034
# min        -8.000000      -4.000000
# 25%        -3.000000      -1.000000
# 50%         0.000000       0.000000
# 75%         4.000000       1.000000
# max        30.000000       3.000000
# std         5.683130       1.211385

# %%
subset_test.groupby('rarity').describe()
# Out:
#          released_at                                                      \
#                count                           mean                  min
# rarity
# bonus              9            2014-06-16 00:00:00  2014-06-16 00:00:00
# common         31217  2013-10-02 10:33:48.510106624  1993-08-05 00:00:00
# mythic          7001  2020-05-23 10:56:57.454649088  2008-10-03 00:00:00
# rare           31958  2015-12-19 15:38:34.913323776  1993-08-05 00:00:00
# special          386  2015-05-11 20:16:09.948186624  2006-10-06 00:00:00
# uncommon       21646  2013-07-01 02:06:35.823708672  1993-08-05 00:00:00
#
#                                                                          \
#                           25%                  50%                  75%
# rarity
# bonus     2014-06-16 00:00:00  2014-06-16 00:00:00  2014-06-16 00:00:00
# common    2007-05-04 00:00:00  2016-11-11 00:00:00  2021-06-18 00:00:00
# mythic    2018-12-06 00:00:00  2021-06-19 00:00:00  2022-12-02 00:00:00
# ...

# %%
subset_test.sample()
# Out:
#                                          id                     name  \
# 81332  e140a98a-ad97-40c9-a666-9d5055f7edd4  Spinnerette, Arachnobat
#
#       released_at  mana_cost  cmc color_identity                     keywords  \
# 81332  2022-10-07  {3}{B}{G}  5.0         [B, G]  [Open an Attraction, Reach]
#
#                                               legalities  set  set_name  ...  \
# 81332  {'standard': 'not_legal', 'future': 'not_legal...  unf  Unfinity  ...
#
#                                    type_line  \
# 81332  Legendary Creature — Spider Performer
#
#                                              oracle_text flavor_text  \
# 81332  Reach\nWhen Spinnerette, Arachnobat enters the...         NaN
#
#       edhrec_rank  produced_mana loyalty printed_name flavor_name  \
# 81332     13813.0            NaN     NaN          NaN         NaN
#
#       life_modifier  hand_modifier
# 81332           NaN            NaN
#
# [1 rows x 21 columns]
